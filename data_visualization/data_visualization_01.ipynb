# %%
import pandas as pd

# %%
df1 = pd.read_csv('Data03.csv')

# %%
print(df1.shape)
df1.head()
# Out:
# (51304, 17)
#          id type_of_contract type_of_contract2 channel    datetime  Term  \
# 0  66758234               렌탈            Normal  서비스 방문  2019-10-20    60
# 1  66755948               렌탈  Extension_Rental  서비스 방문  2019-10-20    60
# 2  66756657               렌탈            Normal  홈쇼핑/방송  2019-10-20    60
# 3  66423450              멤버십               TAS   렌탈재계약  2019-10-20    12
# 4  66423204              멤버십               TAS   렌탈재계약  2019-10-20    12
#
#   payment_type product  amount state  overdue_count overdue  credit rating  \
# 0          CMS      K1   96900  계약확정              0      없음            9.0
# 1         카드이체      K1  102900  계약확정              0      없음            2.0
# 2          CMS      K1   96900  계약확정              0      없음            8.0
# 3          CMS      K1   66900  계약확정              0      없음            5.0
# 4          CMS      K1   66900  해약확정             12      있음            8.0
#
#     bank cancellation   age  Mileage
# ...

# %%
# 어떤 데이터를 기준으로 정렬되어 있는지, Key값을 파악하는게 진짜 중요함
# 위와 같은 데이터는 datetime을 통해 정렬되어 있음

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51304 entries, 0 to 51303
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 51304 non-null  int64
#  1   type_of_contract   51300 non-null  object
#  2   type_of_contract2  51303 non-null  object
#  3   channel            51304 non-null  object
#  4   datetime           51304 non-null  object
#  5   Term               51304 non-null  int64
#  6   payment_type       51304 non-null  object
#  7   product            51303 non-null  object
#  8   amount             51304 non-null  int64
#  9   state              51304 non-null  object
#  10  overdue_count      51304 non-null  int64
#  11  overdue            51302 non-null  object
#  12  credit rating      42521 non-null  float64
#  13  bank               48544 non-null  object
#  14  cancellation       51279 non-null  object
#  15  age                40509 non-null  float64
# ...

# %% [markdown]
# # 단일변수

# %%
import seaborn as sns

# %%
# 문자(object)데이터는 보통 빈도수를 많이 봄
df1['type_of_contract'] # 렌탈인지 멤버십인지 확인이 가능
df1['type_of_contract'].value_counts()
# Out:
# 렌탈     46481
# 멤버십     4819
# Name: type_of_contract, dtype: int64

# %%
sns.countplot(data=df1, x='type_of_contract')
# Out:
# <AxesSubplot:xlabel='type_of_contract', ylabel='count'>
# C:\Users\Sanghyun Yun\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47116 (\N{HANGUL SYLLABLE REN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Sanghyun Yun\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53448 (\N{HANGUL SYLLABLE TAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Sanghyun Yun\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47716 (\N{HANGUL SYLLABLE MEM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Sanghyun Yun\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df1['product'].value_counts()
# Out:
# K1    39134
# K2     8995
# K3     2082
# K5      645
# K4      327
# K6      120
# Name: product, dtype: int64

# %%
sns.countplot(data=df1, x='product', hue='type_of_contract2')
# Out:
# <AxesSubplot:xlabel='product', ylabel='count'>

# %%
import matplotlib.pyplot as plt # pyplot: 파이썬 내에서 그래프 출력과 연관
import matplotlib as mpl # 한글폰트 설정, 글씨체 흐릿한거 뚜렷하게 생성해줌

# %%
mpl.rc('font', family='Malgun Gothic')

# %%
sns.countplot(data=df1, x='type_of_contract')
# Out:
# <AxesSubplot:xlabel='type_of_contract', ylabel='count'>

# %%
plt.figure(figsize=[10,5]) # plt.figure(figsize[x축 사이즈, y축 사이즈])
sns.countplot(data=df1, x='product', hue='type_of_contract2')
plt.legend(loc='right') # plt.legend(loc='') 범례 위치 조정
plt.savefig('img1.png') # plt.savefig('ex.png')그래프 저장

# %%
plt.title("계약 유형 별, 고객 연령 분포")
sns.histplot(data=df1, x='age', kde=True, hue='type_of_contract') # 숫자형 데이터에는 histplot을 사용, kde=확률분포
plt.savefig('img2.png')

# %%
sns.countplot(data=df1, x='bank') # 은행 이름이 다 겹쳐서 나오게 되는 경우....
# Out:
# <AxesSubplot:xlabel='bank', ylabel='count'>

# %%
plt.figure(figsize=[5,10]) # 그래프의 y축 사이즈를 증가시킴
sns.countplot(data=df1, y='bank') # y축으로 변경해도 겹치는 경우
# Out:
# <AxesSubplot:xlabel='count', ylabel='bank'>

# %%
# 데이터가 없는 은행은 삭제하고, 상위 순10개 나열
order_list = df1['bank'].value_counts().index.tolist() # 높은 순서의 은행만 출력할 수 있게됨

# %%
sns.countplot(data=df1, x='bank', order=['국민은행', '롯데카드', '농협은행', '신한은행']) # order를 사용하면 순서대로 출력
# Out:
# <AxesSubplot:xlabel='bank', ylabel='count'>

# %%
sns.countplot(data=df1, x='bank', order=order_list) # order_list를 통해 높은 순으로 출력이 가능
# Out:
# <AxesSubplot:xlabel='bank', ylabel='count'>

# %%
plt.figure(figsize=[10,5])
sns.countplot(data=df1, x='bank', order=order_list[0:10])
# Out:
# <AxesSubplot:xlabel='bank', ylabel='count'>
